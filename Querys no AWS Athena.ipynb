# %% [markdown]
# # AWS Athena.

# %% [markdown]
# Antes de começar as consultas, é feita a criação da tabela, utilizando os dados enriquecidos previamente.

# %% [markdown]
# ```sql
# CREATE EXTERNAL TABLE `telegram`(
#   `message_id` bigint,
#   `user_id` bigint,
#   `user_is_bot` boolean,
#   `user_first_name` string,
#   `chat_id` bigint,
#   `chat_type` string,
#   `text` string,
#   `date` bigint)
# PARTITIONED BY (
#   `context_date` date)
# ROW FORMAT SERDE
#   'org.apache.hadoop.hive.ql.io.parquet.serde.ParquetHiveSerDe'
# STORED AS INPUTFORMAT
#   'org.apache.hadoop.hive.ql.io.parquet.MapredParquetInputFormat'
# OUTPUTFORMAT
#   'org.apache.hadoop.hive.ql.io.parquet.MapredParquetOutputFormat'
# LOCATION
#   's3://projetoebac-datalake-enriched/telegram/'
# ```

# %% [markdown]
# * É adicionada as partições (esse é um processo manual, ou seja, toda a vez que for adicionar uma nova partição, é necessario informar para o Athena novamente)

# %% [markdown]
# ```sql
# MSCK REPAIR TABLE `telegram`;
# ```

# %% [markdown]
# # Consultas utilizadas AWS Athena.

# %% [markdown]
# ### Quantidade de mensagens por dia.

# %% [markdown]
# ```sql
# SELECT
#   context_date,
#   count(1) AS "message_amount"
# FROM "telegram"
# GROUP BY context_date
# ORDER BY context_date DESC
# ```

# %% [markdown]
# * Resposta:

# %% [markdown]
# ![Athena (msg por dia).png](data:image/png;base64,...)

# %% [markdown]
# ### Quantidade de mensagens por usuarios por dia.

# %% [markdown]
# ```sql
# SELECT
#   user_id,
#   user_first_name,
#   context_date,
#   count(1) AS "message_amount"
# FROM "telegram"
# GROUP BY
#   user_id,
#   user_first_name,
#   context_date
# ORDER BY context_date DESC
# ```

# %% [markdown]
# * Resposta:

# %% [markdown]
# ![Qt msg de usuarios por dia.png](data:image/png;base64,...)

# %% [markdown]
# ### Média do tamanho das mensagens por usuário por dia.

# %% [markdown]
# ```sql
# SELECT
#   user_id,
#   user_first_name,
#   context_date,
#   CAST(AVG(length(text)) AS INT) AS "average_message_length"
# FROM "telegram"
# GROUP BY
#   user_id,
#   user_first_name,
#   context_date
# ORDER BY context_date DESC
# ```

# %% [markdown]
# * Resposta:

# %% [markdown]
# ![media tamanho das msgs.png](data:image/png;base64,...)

# %% [markdown]
# ### Quantidade de mensagens por hora por dia da semana por número da semana.

# %% [markdown]
# ```sql
# WITH
# parsed_date_cte AS (
#     SELECT
#         *,
#         CAST(date_format(from_unixtime("date"),'%Y-%m-%d %H:%i:%s') AS timestamp) AS parsed_date
#     FROM "telegram"
# ),
# hour_week_cte AS (
#     SELECT
#         *,
#         EXTRACT(hour FROM parsed_date) AS parsed_date_hour,
#         EXTRACT(dow FROM parsed_date) AS parsed_date_weekday,
#         EXTRACT(week FROM parsed_date) AS parsed_date_weeknum
#     FROM parsed_date_cte
# )
# SELECT
#     parsed_date_hour,
#     parsed_date_weekday,
#     parsed_date_weeknum,
#     count(1) AS "message_amount"
# FROM hour_week_cte
# GROUP BY
#     parsed_date_hour,
#     parsed_date_weekday,
#     parsed_date_weeknum
# ORDER BY
#     parsed_date_weeknum,
#     parsed_date_weekday
# ```

# %% [markdown]
# * Resposta:

# %% [markdown]
# ![msg por hra por dia da sem por número da sem.png](data:image/png;base64,...)
